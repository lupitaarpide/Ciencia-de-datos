# %% [markdown]
# # Actividad 1.3
# Instalacion e importacion de librerias

# %%
import numpy
import pandas
import matplotlib
import seaborn
import sklearn

# %% [markdown]
# ## Comprobacion de instalacion de librerias
#
# ---
# ![Captura](img/Cap.png)
